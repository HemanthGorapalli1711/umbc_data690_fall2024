# %% [markdown]
# # 10/16/2024

# %%
import pandas as pd
import plotly.express as px

import warnings
warnings.filterwarnings('ignore')

pd.set_option("display.max_rows", None)

df = pd.read_csv("https://raw.githubusercontent.com/wcj365/python-stats-dataviz/refs/heads/master/fall2024/data/World_Development_Indicators_(WDI).csv")

print(df.shape)
df.sample(3)
# Out:
# (4123, 9)
#       Year     Country  GDP per capita (current US$)  \
# 2375  2004  Mauritania                    801.778683
# 811   2017    Colombia                   6449.970987
# 24    2009     Albania                   4114.134033
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 2375                                   61.593          2946575.0          MRT
# 811                                    76.646         48351671.0          COL
# 24                                     77.781          2927519.0          ALB
#
#                           Region         Income Group Lending Type
# 2375         Sub-Saharan Africa   Lower middle income          IDA
# 811   Latin America & Caribbean   Upper middle income         IBRD
# 24         Europe & Central Asia  Upper middle income         IBRD

# %%
column_names_dict = {
    "GDP per capita (current US$)" : "GDP per Capita",
    "Life expectancy at birth, total (years)" : "Life Expectancy",
    "Population, total" : "Population"
}

df = df.rename(columns=column_names_dict)
df.sample(3)
# Out:
#       Year       Country  GDP per Capita  Life Expectancy  Population  \
# 2919  2016      Paraguay     5759.042198           73.534   6266615.0
# 3799  2022  Turkmenistan     8792.548504              NaN   6430770.0
# 3123  2011    San Marino    55815.285261              NaN     32495.0
#
#      Country Code                      Region         Income Group  \
# 2919          PRY  Latin America & Caribbean   Upper middle income
# 3799          TKM       Europe & Central Asia  Upper middle income
# 3123          SMR       Europe & Central Asia          High income
#
#         Lending Type
# 2919            IBRD
# 3799            IBRD
# 3123  Not classified

# %%
df.sample(3).T
# Out:
#                                 2739                 868                  395
# Year                            2007                 2017                 2019
# Country                      Nigeria          Congo, Rep.                Benin
# GDP per Capita           1876.413033          2227.720139          1170.885995
# Life Expectancy               50.033                63.76               60.454
# Population               148294028.0            5312340.0           12290444.0
# Country Code                     NGA                  COG                  BEN
# Region           Sub-Saharan Africa   Sub-Saharan Africa   Sub-Saharan Africa
# Income Group     Lower middle income  Lower middle income  Lower middle income
# Lending Type                   Blend                Blend                  IDA

# %% [markdown]
# ## Section One
#
# Summary Statistics with describe() function

# %%
df[["Population","Life Expectancy"]].describe()
# Out:
#          Population  Life Expectancy
# count  4.123000e+03      3777.000000
# mean   3.319575e+07        71.060853
# std    1.316430e+08         8.499806
# min    9.791000e+03        42.125000
# 25%    7.436200e+05        65.351000
# 50%    5.872624e+06        72.765000
# 75%    2.148494e+07        77.529000
# max    1.417173e+09        85.497561

# %%
df.describe()
# Out:
#              Year  GDP per Capita  Life Expectancy    Population
# count  4123.00000     3962.000000      3777.000000  4.123000e+03
# mean   2013.00000    17007.692848        71.060853  3.319575e+07
# std       5.47789    25733.109164         8.499806  1.316430e+08
# min    2004.00000      128.538423        42.125000  9.791000e+03
# 25%    2008.00000     1862.892400        65.351000  7.436200e+05
# 50%    2013.00000     6048.304202        72.765000  5.872624e+06
# 75%    2018.00000    22137.309568        77.529000  2.148494e+07
# max    2022.00000   240862.182448        85.497561  1.417173e+09

# %%
df.describe(include="object")
# Out:
#             Country Country Code                 Region Income Group  \
# count          4123         4123                   4123         4123
# unique          217          217                      7            5
# top     Afghanistan          AFG  Europe & Central Asia  High income
# freq             19           19                   1102         1558
#
#           Lending Type
# count             4123
# unique               4
# top     Not classified
# freq              1387

# %%
df.describe(include="object").T
# Out:
#              count unique                    top  freq
# Country       4123    217            Afghanistan    19
# Country Code  4123    217                    AFG    19
# Region        4123      7  Europe & Central Asia  1102
# Income Group  4123      5            High income  1558
# Lending Type  4123      4         Not classified  1387

# %% [markdown]
# ## Section Two
#
# Compute quartiles and transform a numerical column into a categorical column based on the quartiles.

# %%
def assign_quartile(gdp):
    if gdp <= 1862.89:
        quartile = "1st Quartile (<=25%)"
    elif gdp > 1862.89 and gdp <= 6048.30:
        quartile = "2nd Quartile (25-50%)"
    elif gdp > 6048.30 and gdp <= 22137.31:
        quartile = "3rd Quartile (50-75%)"
    else:
        quartile = "4th Quartile (>75%)"
    return quartile


hungary = assign_quartile(14294.25)
hungary
# Out:
# '3rd Quartile (50-75%)'

# %%
df_usa = df[df["Country Code"] == "USA"]
df_usa
# Out:
#       Year        Country  GDP per Capita  Life Expectancy   Population  \
# 3914  2004  United States    41724.631629        77.487805  292805298.0
# 3915  2005  United States    44123.407068        77.487805  295516599.0
# 3916  2006  United States    46302.000880        77.687805  298379912.0
# 3917  2007  United States    48050.223777        77.987805  301231207.0
# 3918  2008  United States    48570.045980        78.039024  304093966.0
# 3919  2009  United States    47194.943355        78.390244  306771529.0
# 3920  2010  United States    48650.643128        78.541463  309327143.0
# 3921  2011  United States    50065.966504        78.641463  311583481.0
# 3922  2012  United States    51784.418574        78.741463  313877662.0
# 3923  2013  United States    53291.127689        78.741463  316059947.0
# 3924  2014  United States    55123.849787        78.841463  318386329.0
# 3925  2015  United States    56762.729452        78.690244  320738994.0
# 3926  2016  United States    57866.744934        78.539024  323071755.0
# 3927  2017  United States    59907.754261        78.539024  325122128.0
# 3928  2018  United States    62823.309438        78.639024  326838199.0
# 3929  2019  United States    65120.394663        78.787805  328329953.0
# 3930  2020  United States    63528.634303        76.980488  331511512.0
# 3931  2021  United States    70219.472454        76.329268  332031554.0
# 3932  2022  United States    76329.582265              NaN  333287557.0
#
#      Country Code         Region Income Group    Lending Type
# 3914          USA  North America  High income  Not classified
# 3915          USA  North America  High income  Not classified
# 3916          USA  North America  High income  Not classified
# 3917          USA  North America  High income  Not classified
# 3918          USA  North America  High income  Not classified
# 3919          USA  North America  High income  Not classified
# 3920          USA  North America  High income  Not classified
# 3921          USA  North America  High income  Not classified
# 3922          USA  North America  High income  Not classified
# 3923          USA  North America  High income  Not classified
# 3924          USA  North America  High income  Not classified
# 3925          USA  North America  High income  Not classified
# 3926          USA  North America  High income  Not classified
# 3927          USA  North America  High income  Not classified
# 3928          USA  North America  High income  Not classified
# 3929          USA  North America  High income  Not classified
# 3930          USA  North America  High income  Not classified
# 3931          USA  North America  High income  Not classified
# 3932          USA  North America  High income  Not classified

# %%
assign_quartile(76329.58)
# Out:
# '4th Quartile (>75%)'

# %%
df_2020 = df[df["Year"] == 2020]
print(df_2020.shape[0])
print(f"There are {df_2020.shape[0]} countries in the 2020 dataset")
df_2020.sample(3)
# Out:
# 217
# There are 217 countries in the 2020 dataset
#       Year   Country  GDP per Capita  Life Expectancy  Population  \
# 3664  2020  Thailand     7001.785460         79.27400  71475664.0
# 4101  2020    Zambia      956.831729         62.38000  18927715.0
# 928   2020   Croatia    14269.908855         77.72439   4047680.0
#
#      Country Code                 Region         Income Group Lending Type
# 3664          THA    East Asia & Pacific  Upper middle income         IBRD
# 4101          ZMB    Sub-Saharan Africa   Lower middle income          IDA
# 928           HRV  Europe & Central Asia          High income         IBRD

# %%
# Tuple
df_2020.shape
# Out:
# (217, 9)

# %% [markdown]
# ## In-class Exercise
#
# Create a new column call "GDP Quartile" in the df_2020 dataframe and assign each country the quartile it belongs to by applying the assign_quartile() function.

# %%
df_2020["GDP Quartile"] = df_2020["GDP per Capita"].apply(assign_quartile)

print(df_2020.shape[0])
print(df_2020["GDP Quartile"].value_counts())
# Out:
# 217
# GDP Quartile
# 4th Quartile (>75%)      61
# 2nd Quartile (25-50%)    58
# 3rd Quartile (50-75%)    54
# 1st Quartile (<=25%)     44
# Name: count, dtype: int64

# %%
df_2020.sample(10)
# Out:
#       Year           Country  GDP per Capita  Life Expectancy  Population  \
# 1460  2020            Greece    17617.291506        81.287805  10698599.0
# 852   2020  Congo, Dem. Rep.      524.666686        59.739000  92853164.0
# 396   2020             Benin     1240.733155        60.088000  12643123.0
# 4025  2020          Viet Nam     3586.347176        75.378000  96648685.0
# 1099  2020           Ecuador     5645.199290        72.153000  17588595.0
# 149   2020         Argentina     8500.837939        75.892000  45376763.0
# 434   2020            Bhutan     3181.339747        71.609000    772506.0
# 35    2020           Albania     5343.037704        76.989000   2837849.0
# 2600  2020           Namibia     4252.041720        62.829000   2489098.0
# 2619  2020             Nauru    10124.700622        63.437000     12315.0
#
#      Country Code                      Region         Income Group  \
# 1460          GRC       Europe & Central Asia          High income
# 852           COD         Sub-Saharan Africa            Low income
# 396           BEN         Sub-Saharan Africa   Lower middle income
# 4025          VNM         East Asia & Pacific  Lower middle income
# 1099          ECU  Latin America & Caribbean   Upper middle income
# 149           ARG  Latin America & Caribbean   Upper middle income
# 434           BTN                  South Asia  Lower middle income
# 35            ALB       Europe & Central Asia  Upper middle income
# 2600          NAM         Sub-Saharan Africa   Upper middle income
# 2619          NRU         East Asia & Pacific          High income
#
#         Lending Type           GDP Quartile
# 1460  Not classified  3rd Quartile (50-75%)
# 852              IDA   1st Quartile (<=25%)
# 396              IDA   1st Quartile (<=25%)
# 4025            IBRD  2nd Quartile (25-50%)
# 1099            IBRD  2nd Quartile (25-50%)
# 149             IBRD  3rd Quartile (50-75%)
# 434              IDA  2nd Quartile (25-50%)
# 35              IBRD  2nd Quartile (25-50%)
# 2600            IBRD  2nd Quartile (25-50%)
# 2619            IBRD  3rd Quartile (50-75%)

# %%
df_4th = df_2020[df_2020["GDP Quartile"] == "4th Quartile (>75%)"]
df_4th.shape
# Out:
# (61, 10)

# %%
", ".join(list(df_4th["Country"]))
# Out:
# "Andorra, Aruba, Australia, Austria, Bahamas, The, Bahrain, Belgium, Bermuda, British Virgin Islands, Brunei Darussalam, Canada, Cayman Islands, Channel Islands, Cyprus, Czechia, Denmark, Eritrea, Estonia, Faroe Islands, Finland, France, Germany, Gibraltar, Greenland, Guam, Hong Kong SAR, China, Iceland, Ireland, Isle of Man, Israel, Italy, Japan, Korea, Dem. People's Rep., Korea, Rep., Kuwait, Liechtenstein, Luxembourg, Macao SAR, China, Malta, Monaco, Netherlands, New Caledonia, New Zealand, Norway, Portugal, Puerto Rico, Qatar, San Marino, Singapore, Sint Maarten (Dutch part), Slovenia, South Sudan, Spain, St. Martin (French part), Sweden, Switzerland, United Arab Emirates, United Kingdom, United States, Venezuela, RB, Virgin Islands (U.S.)"

# %%
quartile_groups = df_2020.groupby("GDP Quartile")["Country"].apply(list)


for quartile, countries in quartile_groups.items():
  print(f"{quartile}:")
  for country in countries:
      print(f"  - {country}")
  print("\n")
# Out:
# 1st Quartile (<=25%):
#   - Afghanistan
#   - Angola
#   - Benin
#   - Burkina Faso
#   - Burundi
#   - Cambodia
#   - Cameroon
#   - Central African Republic
#   - Chad
#   - Comoros
#   - Congo, Dem. Rep.
#   - Ethiopia
#   - Gambia, The
#   - Guinea
#   - Guinea-Bissau
#   - Haiti
#   - Kiribati
#   - Kyrgyz Republic
#   - Lesotho
#   - Liberia
#   - Madagascar
#   - Malawi
#   - Mali
#   - Mauritania
#   - Mozambique
#   - Myanmar
#   - Nepal
#   - Niger
#   - Pakistan
#   - Rwanda
#   - Senegal
#   - Sierra Leone
#   - Somalia
#   - Sudan
#   - Syrian Arab Republic
#   - Tajikistan
#   - Tanzania
#   - Timor-Leste
#   - Togo
#   - Uganda
#   - Uzbekistan
#   - Yemen, Rep.
#   - Zambia
#   - Zimbabwe
#
#
# 2nd Quartile (25-50%):
#   - Albania
#   - Algeria
#   - Armenia
#   - Azerbaijan
#   - Bangladesh
#   - Belize
#   - Bhutan
#   - Bolivia
#   - Botswana
#   - Cabo Verde
#   - Colombia
#   - Congo, Rep.
#   - Cote d'Ivoire
#   - Djibouti
#   - Ecuador
#   - Egypt, Arab Rep.
#   - El Salvador
#   - Eswatini
#   - Fiji
#   - Georgia
#   - Ghana
#   - Guatemala
#   - Honduras
#   - India
#   - Indonesia
#   - Iran, Islamic Rep.
#   - Iraq
#   - Jamaica
#   - Jordan
#   - Kenya
#   - Kosovo
#   - Lao PDR
#   - Lebanon
#   - Marshall Islands
#   - Micronesia, Fed. Sts.
#   - Moldova
#   - Mongolia
#   - Morocco
#   - Namibia
#   - Nicaragua
#   - Nigeria
#   - North Macedonia
#   - Papua New Guinea
#   - Paraguay
#   - Philippines
#   - Samoa
#   - Sao Tome and Principe
#   - Solomon Islands
#   - South Africa
#   - Sri Lanka
#   - Suriname
#   - Tonga
#   - Tunisia
#   - Tuvalu
#   - Ukraine
#   - Vanuatu
#   - Viet Nam
#   - West Bank and Gaza
#
#
# 3rd Quartile (50-75%):
#   - American Samoa
#   - Antigua and Barbuda
#   - Argentina
#   - Barbados
#   - Belarus
#   - Bosnia and Herzegovina
#   - Brazil
#   - Bulgaria
#   - Chile
#   - China
#   - Costa Rica
#   - Croatia
#   - Cuba
#   - Curacao
#   - Dominica
#   - Dominican Republic
#   - Equatorial Guinea
#   - French Polynesia
#   - Gabon
#   - Greece
#   - Grenada
#   - Guyana
#   - Hungary
#   - Kazakhstan
#   - Latvia
#   - Libya
#   - Lithuania
#   - Malaysia
#   - Maldives
#   - Mauritius
#   - Mexico
#   - Montenegro
#   - Nauru
#   - Northern Mariana Islands
#   - Oman
#   - Palau
#   - Panama
#   - Peru
#   - Poland
#   - Romania
#   - Russian Federation
#   - Saudi Arabia
#   - Serbia
#   - Seychelles
#   - Slovak Republic
#   - St. Kitts and Nevis
#   - St. Lucia
#   - St. Vincent and the Grenadines
#   - Thailand
#   - Trinidad and Tobago
#   - Turkiye
#   - Turkmenistan
#   - Turks and Caicos Islands
#   - Uruguay
#
#
# 4th Quartile (>75%):
#   - Andorra
#   - Aruba
#   - Australia
#   - Austria
#   - Bahamas, The
#   - Bahrain
#   - Belgium
#   - Bermuda
#   - British Virgin Islands
#   - Brunei Darussalam
#   - Canada
#   - Cayman Islands
#   - Channel Islands
#   - Cyprus
#   - Czechia
#   - Denmark
#   - Eritrea
#   - Estonia
#   - Faroe Islands
#   - Finland
#   - France
#   - Germany
#   - Gibraltar
#   - Greenland
#   - Guam
#   - Hong Kong SAR, China
#   - Iceland
#   - Ireland
#   - Isle of Man
#   - Israel
#   - Italy
#   - Japan
#   - Korea, Dem. People's Rep.
#   - Korea, Rep.
#   - Kuwait
#   - Liechtenstein
#   - Luxembourg
#   - Macao SAR, China
#   - Malta
#   - Monaco
#   - Netherlands
#   - New Caledonia
#   - New Zealand
#   - Norway
#   - Portugal
#   - Puerto Rico
#   - Qatar
#   - San Marino
#   - Singapore
#   - Sint Maarten (Dutch part)
#   - Slovenia
#   - South Sudan
#   - Spain
#   - St. Martin (French part)
#   - Sweden
#   - Switzerland
#   - United Arab Emirates
#   - United Kingdom
#   - United States
#   - Venezuela, RB
#   - Virgin Islands (U.S.)

# %%
for quartile, countries in quartile_groups.items():
  print(f"{quartile}:")
  for country in countries:
      print(f"  - {country}")
  print("\n")
# Out:
# 1st Quartile (<=25%):
#   - Afghanistan
#   - Angola
#   - Benin
#   - Burkina Faso
#   - Burundi
#   - Cambodia
#   - Cameroon
#   - Central African Republic
#   - Chad
#   - Comoros
#   - Congo, Dem. Rep.
#   - Ethiopia
#   - Gambia, The
#   - Guinea
#   - Guinea-Bissau
#   - Haiti
#   - Kiribati
#   - Kyrgyz Republic
#   - Lesotho
#   - Liberia
#   - Madagascar
#   - Malawi
#   - Mali
#   - Mauritania
#   - Mozambique
#   - Myanmar
#   - Nepal
#   - Niger
#   - Pakistan
#   - Rwanda
#   - Senegal
#   - Sierra Leone
#   - Somalia
#   - Sudan
#   - Syrian Arab Republic
#   - Tajikistan
#   - Tanzania
#   - Timor-Leste
#   - Togo
#   - Uganda
#   - Uzbekistan
#   - Yemen, Rep.
#   - Zambia
#   - Zimbabwe
#
#
# 2nd Quartile (25-50%):
#   - Albania
#   - Algeria
#   - Armenia
#   - Azerbaijan
#   - Bangladesh
#   - Belize
#   - Bhutan
#   - Bolivia
#   - Botswana
#   - Cabo Verde
#   - Colombia
#   - Congo, Rep.
#   - Cote d'Ivoire
#   - Djibouti
#   - Ecuador
#   - Egypt, Arab Rep.
#   - El Salvador
#   - Eswatini
#   - Fiji
#   - Georgia
#   - Ghana
#   - Guatemala
#   - Honduras
#   - India
#   - Indonesia
#   - Iran, Islamic Rep.
#   - Iraq
#   - Jamaica
#   - Jordan
#   - Kenya
#   - Kosovo
#   - Lao PDR
#   - Lebanon
#   - Marshall Islands
#   - Micronesia, Fed. Sts.
#   - Moldova
#   - Mongolia
#   - Morocco
#   - Namibia
#   - Nicaragua
#   - Nigeria
#   - North Macedonia
#   - Papua New Guinea
#   - Paraguay
#   - Philippines
#   - Samoa
#   - Sao Tome and Principe
#   - Solomon Islands
#   - South Africa
#   - Sri Lanka
#   - Suriname
#   - Tonga
#   - Tunisia
#   - Tuvalu
#   - Ukraine
#   - Vanuatu
#   - Viet Nam
#   - West Bank and Gaza
#
#
# 3rd Quartile (50-75%):
#   - American Samoa
#   - Antigua and Barbuda
#   - Argentina
#   - Barbados
#   - Belarus
#   - Bosnia and Herzegovina
#   - Brazil
#   - Bulgaria
#   - Chile
#   - China
#   - Costa Rica
#   - Croatia
#   - Cuba
#   - Curacao
#   - Dominica
#   - Dominican Republic
#   - Equatorial Guinea
#   - French Polynesia
#   - Gabon
#   - Greece
#   - Grenada
#   - Guyana
#   - Hungary
#   - Kazakhstan
#   - Latvia
#   - Libya
#   - Lithuania
#   - Malaysia
#   - Maldives
#   - Mauritius
#   - Mexico
#   - Montenegro
#   - Nauru
#   - Northern Mariana Islands
#   - Oman
#   - Palau
#   - Panama
#   - Peru
#   - Poland
#   - Romania
#   - Russian Federation
#   - Saudi Arabia
#   - Serbia
#   - Seychelles
#   - Slovak Republic
#   - St. Kitts and Nevis
#   - St. Lucia
#   - St. Vincent and the Grenadines
#   - Thailand
#   - Trinidad and Tobago
#   - Turkiye
#   - Turkmenistan
#   - Turks and Caicos Islands
#   - Uruguay
#
#
# 4th Quartile (>75%):
#   - Andorra
#   - Aruba
#   - Australia
#   - Austria
#   - Bahamas, The
#   - Bahrain
#   - Belgium
#   - Bermuda
#   - British Virgin Islands
#   - Brunei Darussalam
#   - Canada
#   - Cayman Islands
#   - Channel Islands
#   - Cyprus
#   - Czechia
#   - Denmark
#   - Eritrea
#   - Estonia
#   - Faroe Islands
#   - Finland
#   - France
#   - Germany
#   - Gibraltar
#   - Greenland
#   - Guam
#   - Hong Kong SAR, China
#   - Iceland
#   - Ireland
#   - Isle of Man
#   - Israel
#   - Italy
#   - Japan
#   - Korea, Dem. People's Rep.
#   - Korea, Rep.
#   - Kuwait
#   - Liechtenstein
#   - Luxembourg
#   - Macao SAR, China
#   - Malta
#   - Monaco
#   - Netherlands
#   - New Caledonia
#   - New Zealand
#   - Norway
#   - Portugal
#   - Puerto Rico
#   - Qatar
#   - San Marino
#   - Singapore
#   - Sint Maarten (Dutch part)
#   - Slovenia
#   - South Sudan
#   - Spain
#   - St. Martin (French part)
#   - Sweden
#   - Switzerland
#   - United Arab Emirates
#   - United Kingdom
#   - United States
#   - Venezuela, RB
#   - Virgin Islands (U.S.)

# %%
df_2020 = df_2020.dropna()
df_2020["GDP (Rounded)"] = df_2020["GDP per Capita"].apply(round)
df_2020.sample(5)
# Out:
#       Year       Country  GDP per Capita  Life Expectancy  Population  \
#
= pd.read_csv("https://raw.githubusercontent.com/wcj365/python-stats-dataviz/refs/heads/master/fall2024/data/World_Development_Indicators_(WDI).csv")  # or use another method to load data

# Separate numerical and categorical columns
numerical_columns = df.select_dtypes(include=['number']).columns
categorical_columns = df.select_dtypes(include=['object', 'category']).columns

# Summary for numerical columns
numerical_summary = df[numerical_columns].describe()
print("Numerical Summary:")
print(numerical_summary)

# Summary for categorical columns (unique counts and frequencies)
categorical_summary = df[categorical_columns].apply(lambda x: x.value_counts()).T
print("Categorical Summary:")
print(categorical_summary)

# Saving the data into two excel files
with pd.ExcelWriter('summary_statistics.xlsx') as writer:
    numerical_summary.to_excel(writer, sheet_name='Numerical')
    categorical_summary.to_excel(writer, sheet_name='Categorical')
# Out:
# Numerical Summary:
#              Year  GDP per capita (current US$)  \
# count  4123.00000                   3962.000000
# mean   2013.00000                  17007.692848
# std       5.47789                  25733.109164
# min    2004.00000                    128.538423
# 25%    2008.00000                   1862.892400
# 50%    2013.00000                   6048.304202
# 75%    2018.00000                  22137.309568
# max    2022.00000                 240862.182448
#
#        Life expectancy at birth, total (years)  Population, total
# count                              3777.000000       4.123000e+03
# mean                                 71.060853       3.319575e+07
# std                                   8.499806       1.316430e+08
# min                                  42.125000       9.791000e+03
# 25%                                  65.351000       7.436200e+05
# 50%                                  72.765000       5.872624e+06
# 75%                                  77.529000       2.148494e+07
# max                                  85.497561       1.417173e+09
# Categorical Summary:
#                ABW   AFG   AGO   ALB   AND   ARE   ARG   ARM   ASM   ATG  ...  \
# Country        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Country Code  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  19.0  ...
# Region         NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Income Group   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Lending Type   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#                WSM  West Bank and Gaza   XKX   YEM  Yemen, Rep.   ZAF   ZMB  \
# Country        NaN                19.0   NaN   NaN         19.0   NaN   NaN
# Country Code  19.0                 NaN  19.0  19.0          NaN  19.0  19.0
# Region         NaN                 NaN   NaN   NaN          NaN   NaN   NaN
# Income Group   NaN                 NaN   NaN   NaN          NaN   NaN   NaN
# Lending Type   NaN                 NaN   NaN   NaN          NaN   NaN   NaN
#
#                ZWE  Zambia  Zimbabwe
# Country        NaN    19.0      19.0
# Country Code  19.0     NaN       NaN
# Region         NaN     NaN       NaN
# Income Group   NaN     NaN       NaN
# Lending Type   NaN     NaN       NaN
#
# [5 rows x 449 columns]

# %%
# for df_2020

numerical_summary = df_2020.describe()
print("Numerical Summary Statistics:")
print(numerical_summary)

categorical_summary = df_2020.describe(include="object").T
print("Categorical Summary Statistics:")
print(categorical_summary)


# Saving the data into two excel files
with pd.ExcelWriter('summary_statistics.xlsx') as writer:
    numerical_summary.to_excel(writer, sheet_name='Numerical')
    categorical_summary.to_excel(writer, sheet_name='Categorical')
# Out:
# Numerical Summary Statistics:
#          Year  GDP per Capita  Life Expectancy    Population  GDP (Rounded)  \
# count   202.0      202.000000       202.000000  2.020000e+02     202.000000
# mean   2020.0    16198.267524        72.314599  3.825505e+07   16198.277228
# std       0.0    23391.117592         7.451962  1.446623e+08   23391.118369
# min    2020.0      216.827417        52.777000  1.106900e+04     217.000000
# 25%    2020.0     2188.047693        66.779750  1.307377e+06    2188.250000
# 50%    2020.0     5920.260419        72.871500  6.916570e+06    5920.000000
# 75%    2020.0    20761.211199        77.981750  2.673161e+07   20761.000000
# max    2020.0   165287.186767        85.497561  1.411100e+09  165287.000000
#
#        Population (Million)  Population2 (Million)
# count            202.000000             202.000000
# mean              38.255054              38.255054
# std              144.662308             144.662308
# min                0.011069               0.011069
# 25%                1.307377               1.307377
# 50%                6.916570               6.916570
# 75%               26.731614              26.731614
# max             1411.100000            1411.100000
# Categorical Summary Statistics:
#              count unique                    top freq
# Country        202    202            Afghanistan    1
# Country Code   202    202                    AFG    1
# Region         202      7  Europe & Central Asia   54
# Income Group   202      4            High income   72
# Lending Type   202      4                   IBRD   67
# GDP Quartile   202      4  2nd Quartile (25-50%)   58

# %% [markdown]
# ## Homework Question 2
#
# Create a new column that is the GDP per Capita rounded to 2 decimal points by using the Python's build function "round"
# Hint: apply the round function/method and provide a parameter 2.

# %%
# Apply the round function to GDP per Capita and create a new column
df['GDP per Capita (rounded)'] = df['GDP per capita (current US$)'].apply(lambda x: round(x, 2))

# Display the first few rows to verify the new column
print(df[['GDP per capita (current US$)', 'GDP per Capita (rounded)']].head())
# Out:
#    GDP per capita (current US$)  GDP per Capita (rounded)
# 0                    221.830531                    221.83
# 1                    254.115274                    254.12
# 2                    274.015394                    274.02
# 3                    376.318296                    376.32
# 4                    382.533804                    382.53

# %%
df_2020["GDP per Capita (Rounded)"] = df_2020["GDP per Capita"].apply(lambda x: round(x, 2))

df_2020.sample(5)
# Out:
#       Year          Country  GDP per Capita  Life Expectancy  Population  \
# 2049  2020  Kyrgyz Republic     1256.929226        71.800000   6579900.0
# 2315  2020         Maldives     7216.816371        79.875000    514438.0
# 3569  2020           Sweden    52837.903978        82.356098  10353442.0
# 909   2020    Cote d'Ivoire     2349.069882        59.032000  26811790.0
# 681   2020           Canada    43349.677856        81.670488  38007166.0
#
#      Country Code                 Region         Income Group    Lending Type  \
# 2049          KGZ  Europe & Central Asia  Lower middle income             IDA
# 2315          MDV             South Asia  Upper middle income             IDA
# 3569          SWE  Europe & Central Asia          High income  Not classified
# 909           CIV    Sub-Saharan Africa   Lower middle income             IDA
# 681           CAN          North America          High income  Not classified
#
#                GDP Quartile  GDP (Rounded)  Population (Million)  \
# 2049   1st Quartile (<=25%)           1257              6.579900
# 2315  3rd Quartile (50-75%)           7217              0.514438
# 3569    4th Quartile (>75%)          52838             10.353442
# 909   2nd Quartile (25-50%)           2349             26.811790
# 681     4th Quartile (>75%)          43350             38.007166
#
#       Population2 (Million)  GDP per Capita (Rounded)
# 2049               6.579900                   1256.93
# 2315               0.514438                   7216.82
# 3569              10.353442                  52837.90
# 909               26.811790                   2349.07
# 681               38.007166                  43349.68

# %% [markdown]
# ## Homework Question 3 (bonus, will cover next week)
#
# step 1 - create a column "Life Expectancy Quartile" similar to the GDP per Capita Quartile above.
# Step 2 - Create a column "health and wealth status" based on the following definition
# - rich and healthy (1st GDP per capita quartile and 1st life expentancy quartile)
# - poor and unhealthy ((4th GDP per capita quartile and 4th life expentancy quartile)
# - rich and unhealthy (1st GDP per capita quartile and 4th life expentancy quartile)
# - poor and healthy ((4th GDP per capita quartile and 1st life expentancy quartile)
# - Other

# %%
# Step 1: Create the "GDP per Capita Quartile" and "Life Expectancy Quartile"

# Dropping NA values from the relevant columns for clean quartile calculation

df = df.dropna(subset=['GDP per capita (current US$)', 'Life expectancy at birth, total (years)'])

# Create GDP per Capita Quartile
df['GDP per Capita Quartile'] = pd.qcut(df['GDP per capita (current US$)'], 4, labels=[1, 2, 3, 4])

# Create Life Expectancy Quartile
df['Life Expectancy Quartile'] = pd.qcut(df['Life expectancy at birth, total (years)'], 4, labels=[1, 2, 3, 4])

# Step 2: Create the "health and wealth status" column based on the given definition
def health_wealth_status(row):
    if row['GDP per Capita Quartile'] == 1 and row['Life Expectancy Quartile'] == 1:
        return 'rich and healthy'
    elif row['GDP per Capita Quartile'] == 4 and row['Life Expectancy Quartile'] == 4:
        return 'poor and unhealthy'
    elif row['GDP per Capita Quartile'] == 1 and row['Life Expectancy Quartile'] == 4:
        return 'rich and unhealthy'
    elif row['GDP per Capita Quartile'] == 4 and row['Life Expectancy Quartile'] == 1:
        return 'poor and healthy'
    else:
        return 'Other'

# Apply the function to each row to create the new column
df['health and wealth status'] = df.apply(health_wealth_status, axis=1)

# Display the first few rows to verify the results
print(df[['GDP per capita (current US$)', 'Life expectancy at birth, total (years)',
          'GDP per Capita Quartile', 'Life Expectancy Quartile', 'health and wealth status']].head())
# Out:
#    GDP per capita (current US$)  Life expectancy at birth, total (years)  \
# 0                    221.830531                                   57.944
# 1                    254.115274                                   58.361
# 2                    274.015394                                   58.684
# 3                    376.318296                                   59.111
# 4                    382.533804                                   59.852
#
#   GDP per Capita Quartile Life Expectancy Quartile health and wealth status
# 0                       1                        1         rich and healthy
# 1                       1                        1         rich and healthy
# 2                       1                        1         rich and healthy
# 3                       1                        1         rich and healthy
# 4                       1                        1         rich and healthy

# %%
df.sample(55)
# Out:
#       Year                 Country  GDP per capita (current US$)  \
# 2516  2012              Montenegro                   6586.399703
# 800   2006                Colombia                   3782.603496
# 1781  2018                 Ireland                  79446.939109
# 1161  2006                 Eritrea                    420.528740
# 2231  2012        Macao SAR, China                  74111.601186
# 3420  2004               Sri Lanka                   1060.136943
# 1511  2014                    Guam                  33483.941436
# 1729  2004      Iran, Islamic Rep.                   2751.793042
# 5     2009             Afghanistan                    453.387382
# 454   2021                 Bolivia                   3345.023002
# 2729  2016                   Niger                    497.036121
# 1902  2006              Kazakhstan                   5291.574004
# 2138  2014                 Liberia                    713.734882
# 3080  2006                  Rwanda                    358.139227
# 487   2016                Botswana                   6411.551666
# 1032  2010                Djibouti                   1227.820853
# 3192  2004                  Serbia                   3502.802924
# 3222  2015              Seychelles                  14894.485783
# 935   2008                    Cuba                   4992.824494
# 1393  2010                 Germany                  41572.455948
# 3646  2021                Tanzania                   1146.031982
# 1285  2016                 Finland                  43814.026506
# 1474  2015               Greenland                  44536.354971
# 11    2015             Afghanistan                    566.881133
# 385   2009                   Benin                   1061.718360
# 3380  2021            South Africa                   7073.612754
# 1779  2016                 Ireland                  62784.065688
# 1925  2010                   Kenya                   1093.639624
# 866   2015             Congo, Rep.                   2455.347910
# 602   2017                 Burundi                    244.145422
# 1799  2017             Isle of Man                  83510.303746
# 2770  2019         North Macedonia                   6070.388054
# 1587  2014                  Guyana                   5495.377084
# 2011  2020                  Kosovo                   4310.934002
# 1199  2006                Eswatini                   3053.932571
# 3147  2016   Sao Tome and Principe                   1428.257908
# 2046  2017         Kyrgyz Republic                   1242.770220
# 1903  2007              Kazakhstan                   6771.416620
# 2233  2014        Macao SAR, China                  90873.602487
# 39    2005                 Algeria                   3131.328190
# 2120  2015                 Lesotho                   1113.836835
# 652   2010                Cameroon                   1383.813865
# 2217  2017              Luxembourg                 110193.213797
# 3608  2021    Syrian Arab Republic                    420.622705
# 3293  2010         Slovak Republic                  16908.847956
# 429   2015                  Bhutan                   2695.636924
# 3466  2012               St. Lucia                   9231.576254
# 2990  2011                Portugal                  23217.295497
# 1318  2011        French Polynesia                  21747.988842
# 1772  2009                 Ireland                  52133.090616
# 196   2010               Australia                  52147.024194
# 3416  2019                   Spain                  29581.518551
# 2554  2012              Mozambique                    681.492129
# 458   2006  Bosnia and Herzegovina                   3170.174783
# 502   2012                  Brazil                  12327.513101
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 
# 2233                  90873.60                       4
# 39                     3131.33                       2
# 2120                   1113.84                       1
# 652                    1383.81                       1
# 2217                 110193.21                       4
# 3608                    420.62                       1
# 3293                  16908.85                       3
# 429                    2695.64                       2
# 3466                   9231.58                       3
# 2990                  23217.30                       4
# 1318                  21747.99                       4
# 1772                  52133.09                       4
# 196                   52147.02                       4
# 3416                  29581.52                       4
# 2554                    681.49                       1
# 458                    3170.17                       2
# 502                   12327.51                       3
#
#      Life Expectancy Quartile health and wealth status
# 2516                        3                    Other
# 800                         3                    Other
# 1781                        4       poor and unhealthy
# 1161                        1         rich and healthy
# 2231                        4       poor and unhealthy
# 3420                        2                    Other
# 1511                        3                    Other
# 1729                        2                    Other
# 5                           1         rich and healthy
# 454                         1                    Other
# 2729                        1         rich and healthy
# 1902                        2                    Other
# 2138                        1         rich and healthy
# 3080                        1         rich and healthy
# 487                         2                    Other
# 1032                        1         rich and healthy
# 3192                        2                    Other
# 3222                        3                    Other
# 935                         3                    Other
# 1393                        4       poor and unhealthy
# 3646                        2                    Other
# 1285                        4       poor and unhealthy
# 1474                        2                    Other
# 11                          1         rich and healthy
# 385                         1         rich and healthy
# 3380                        1                    Other
# 1779                        4       poor and unhealthy
# 1925                        1         rich and healthy
# 866                         1                    Other
# 602                         1         rich and healthy
# 1799                        4       poor and unhealthy
# 2770                        3                    Other
# 1587                        2                    Other
# 2011                        3                    Other
# 1199                        1                    Other
# 3147                        2                    Other
# 2046                        2                    Other
# 1903                        2                    Other
# 2233                        4       poor and unhealthy
# 39                          2                    Other
# 2120                        1         rich and healthy
# 652                         1         rich and healthy
# 2217                        4       poor and unhealthy
# 3608                        2                    Other
# 3293                        3                    Other
# 429                         2                    Other
# 3466                        3                    Other
# 2990                        4       poor and unhealthy
# 1318                        4       poor and unhealthy
# 1772                        4       poor and unhealthy
# 196                         4       poor and unhealthy
# 3416                        4       poor and unhealthy
# 2554                        1         rich and healthy
# 458                         3                    Other
# 502                         3                    Other

# %%
df_2020.sample(5)
# Out:
#       Year     Country  GDP per Capita  Life Expectancy  Population  \
# 3227  2020  Seychelles    12020.021064        77.236585     98462.0
# 2011  2020      Kosovo     4310.934002        76.567000   1790133.0
# 681   2020      Canada    43349.677856        81.670488  38007166.0
# 1194  2020     Estonia    23595.243684        78.595122   1329522.0
# 2030  2020      Kuwait    24297.710802        76.920000   4360444.0
#
#      Country Code                      Region         Income Group  \
# 3227          SYC         Sub-Saharan Africa           High income
# 2011          XKX       Europe & Central Asia  Upper middle income
# 681           CAN               North America          High income
# 1194          EST       Europe & Central Asia          High income
# 2030          KWT  Middle East & North Africa          High income
#
#         Lending Type           GDP Quartile  GDP (Rounded)  \
# 3227            IBRD  3rd Quartile (50-75%)          12020
# 2011             IDA  2nd Quartile (25-50%)           4311
# 681   Not classified    4th Quartile (>75%)          43350
# 1194  Not classified    4th Quartile (>75%)          23595
# 2030  Not classified    4th Quartile (>75%)          24298
#
#       Population (Million)  Population2 (Million)  GDP per Capita (Rounded)
# 3227              0.098462               0.098462                  12020.02
# 2011              1.790133               1.790133                   4310.93
# 681              38.007166              38.007166                  43349.68
# 1194              1.329522               1.329522                  23595.24
# 2030              4.360444               4.360444                  24297.71
