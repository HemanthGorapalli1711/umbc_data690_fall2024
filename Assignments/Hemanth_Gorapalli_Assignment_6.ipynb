# %% [markdown]
# <a href="https://colab.research.google.com/github/harshithaaah/UMBC_690_FALL2024/blob/main/Assignment/Assignment_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Session 05

# %%
import pandas as pd
import plotly.express as px

pd.set_option("display.max_rows", None)

df = pd.read_csv("https://raw.githubusercontent.com/wcj365/python-stats-dataviz/refs/heads/master/fall2024/data/World_Development_Indicators_(WDI).csv")

df.shape
# Out:
# (4123, 9)

# %%
df.sample(5)
# Out:
#       Year                   Country  GDP per capita (current US$)  \
# 2775  2005  Northern Mariana Islands                  15371.242304
# 3101  2008                     Samoa                   3344.054559
# 3768  2010                   Turkiye                  10622.702044
# 56    2022                   Algeria                   4342.637968
# 2999  2020                  Portugal                  22242.406418
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 2775                                      NaN            69025.0          MNP
# 3101                                 72.15500           191787.0          WSM
# 3768                                 75.06900         73142150.0          TUR
# 56                                        NaN         44903225.0          DZA
# 2999                                 80.97561         10297081.0          PRT
#
#                           Region         Income Group    Lending Type
# 2775         East Asia & Pacific          High income  Not classified
# 3101         East Asia & Pacific  Lower middle income             IDA
# 3768       Europe & Central Asia  Upper middle income            IBRD
# 56    Middle East & North Africa  Lower middle income            IBRD
# 2999       Europe & Central Asia          High income  Not classified

# %%
df.isna().sum()
# Out:
# Year                                         0
# Country                                      0
# GDP per capita (current US$)               161
# Life expectancy at birth, total (years)    346
# Population, total                            0
# Country Code                                 0
# Region                                       0
# Income Group                                 0
# Lending Type                                 0
# dtype: int64

# %%
df[["Year", "Country","GDP per capita (current US$)", "Life expectancy at birth, total (years)"]].sample(5)
# Out:
#       Year               Country  GDP per capita (current US$)  \
# 1137  2020           El Salvador                   3961.726633
# 685   2005        Cayman Islands                           NaN
# 3599  2012  Syrian Arab Republic                   1910.604539
# 1154  2018     Equatorial Guinea                   8719.186870
# 3691  2009                  Togo                    737.953703
#
#       Life expectancy at birth, total (years)
# 1137                                   71.061
# 685                                       NaN
# 3599                                   66.769
# 1154                                   61.191
# 3691                                   57.011

# %%
df2 = df[df["Year"] != 2022]
df2.shape
# Out:
# (3906, 9)

# %%
df2.isna().sum()
# Out:
# Year                                         0
# Country                                      0
# GDP per capita (current US$)               140
# Life expectancy at birth, total (years)    129
# Population, total                            0
# Country Code                                 0
# Region                                       0
# Income Group                                 0
# Lending Type                                 0
# dtype: int64

# %%
df3 = df2.dropna()
df3.isna().sum()
# Out:
# Year                                       0
# Country                                    0
# GDP per capita (current US$)               0
# Life expectancy at birth, total (years)    0
# Population, total                          0
# Country Code                               0
# Region                                     0
# Income Group                               0
# Lending Type                               0
# dtype: int64

# %%
df3.shape
# Out:
# (3641, 9)

# %% [markdown]
# ## Homework Question 1:
#
# to check if this dataset has duplicate rows. If it has, only keep one from the duplicated rows and drop the rest.

# %%
# Homework Question 1: Check for and remove duplicate rows
duplicates = df3.duplicated().sum()
print(f"\n The Number of duplicate rows: {duplicates}")
df4 = df3.drop_duplicates()
print(f"The new shape after removing duplicates: {df4.shape}")
# Out:
#  The Number of duplicate rows: 0
# The new shape after removing duplicates: (3641, 9)

# %% [markdown]
# ## HW Question 2
#
# Find out if there is a relationship between wealth and health
#
# Pick any year worth of data and use plotly express to generate a scatter plot with GDP as x and life expectancy as y.

# %%
data_2020 = df3[df3["Year"] == 2020]

fig = px.scatter(data_2020,
                 x="GDP per capita (current US$)",
                 y="Life expectancy at birth, total (years)",
                 title="GDP vs Life Expectancy (2020)",
                 labels={
                     "GDP per capita (current US$)": "GDP per capita (US$)",
                     "Life expectancy at birth, total (years)": "Life Expectancy (Years)"
                 })
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0300a689-23dd-4b8f-81ae-2f2d5f18bcc3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0300a689-23dd-4b8f-81ae-2f2d5f18bcc3")) {                    Plotly.newPlot(                        "0300a689-23dd-4b8f-81ae-2f2d5f18bcc3",                        [{"hovertemplate":"GDP per capita (US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[512.055098228687,5343.0377039956,3354.15316371593,1450.90511218489,15224.8585890561,8500.83793850534,4505.86774175695,24008.1278217477,51868.2475567823,48789.4978498872,4229.91064904503,23998.2680191207,23433.1872362574,2233.30590129762,16882.5015230162,6542.8645398436,45609.0034936111,5185.1580697602,1240.73315536982,107791.886435134,3181.33974721703,3068.81255516456,6095.10423658487,5875.07060596716,6923.6999117682,27179.3528869398,10148.3423954435,823.552410880968,216.827417480868,3126.39985872259,1577.91173991645,1539.13054519245,43349.677855557,435.469247800022,643.772215694009,57339.5268713567,13173.7847941723,10408.7195541075,5304.28912886641,1519.58677981634,524.666686211495,2011.2694790099,12179.2566735195,2349.06988200418,14269.9088549332,9499.57250428

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="867ef803-de60-487f-aaca-ff926abf49a6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("867ef803-de60-487f-aaca-ff926abf49a6")) {                    Plotly.newPlot(                        "867ef803-de60-487f-aaca-ff926abf49a6",                        [{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eAverage GDP per Capita (US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["East Asia & Pacific","Europe & Central Asia","Latin America & Caribbean ","Middle East & North Africa","North America","South Asia","Sub-Saharan Africa "],"xaxis":"x","y":[15147.706591885904,29378.21105336414,11454.913042455386,15376.014997821934,66809.3072006122,2294.5549548055624,2260.8872490888266],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_ ...

# %%
# Filter data for the year 2020
df_2020 = df3[df3["Year"] == 2020]
print("Shape of the 2020 data:", df_2020.shape)
# Out:
# Shape of the 2020 data: (202, 9)

# %%
df_2020.sample(5)
# Out:
#       Year         Country  GDP per capita (current US$)  \
# 396   2020           Benin                   1240.733155
# 1555  2020          Guinea                   1073.659339
# 263   2020    Bahamas, The                  23998.268019
# 3873  2020         Ukraine                   3751.737305
# 3911  2020  United Kingdom                  40217.009012
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 396                                 60.088000         12643123.0          BEN
# 1555                                59.327000         13205153.0          GIN
# 263                                 72.677000           406471.0          BHS
# 3873                                71.185122         44132049.0          UKR
# 3911                                80.351220         67081234.0          GBR
#
#                           Region         Income Group    Lending Type
# 396          Sub-Saharan Africa   Lower middle income             IDA
# 1555         Sub-Saharan Africa   Lower middle income             IDA
# 263   Latin America & Caribbean           High income  Not classified
# 3873       Europe & Central Asia  Lower middle income            IBRD
# 3911       Europe & Central Asia          High income  Not classified

# %%
# Calculate average GDP per capita by region (using the entire dataset)
df_group = df3.groupby("Region")["GDP per capita (current US$)"].mean().reset_index()
print("\nAverage GDP per capita by region:")
df_group
# Out:
# Average GDP per capita by region:
#                        Region  GDP per capita (current US$)
# 0         East Asia & Pacific                  15147.706592
# 1       Europe & Central Asia                  29378.211053
# 2  Latin America & Caribbean                   11454.913042
# 3  Middle East & North Africa                  15376.014998
# 4               North America                  66809.307201
# 5                  South Asia                   2294.554955
# 6         Sub-Saharan Africa                    2260.887249

# %%
df_group = df_group.reset_index()
df_group
# Out:
#    index                      Region  GDP per capita (current US$)
# 0      0         East Asia & Pacific                  15147.706592
# 1      1       Europe & Central Asia                  29378.211053
# 2      2  Latin America & Caribbean                   11454.913042
# 3      3  Middle East & North Africa                  15376.014998
# 4      4               North America                  66809.307201
# 5      5                  South Asia                   2294.554955
# 6      6         Sub-Saharan Africa                    2260.887249

# %%
# Create the second bar chart (color-coded by region)
fig2 = px.bar(df_group,
              x="Region",
              y="GDP per capita (current US$)",
              color="Region",
              title="Average GDP per Capita by Region (Color-coded)")
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="25dcc47c-e488-4bfb-aada-bb8f42016062" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("25dcc47c-e488-4bfb-aada-bb8f42016062")) {                    Plotly.newPlot(                        "25dcc47c-e488-4bfb-aada-bb8f42016062",                        [{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"East Asia & Pacific","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"East Asia & Pacific","offsetgroup":"East Asia & Pacific","orientation":"v","showlegend":true,"textposition":"auto","x":["East Asia & Pacific"],"xaxis":"x","y":[15147.706591885904],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Europe & Central Asia","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Europe & Central Asia","offsetgroup":"Europe & Central Asia","orientation":"v","showlegend":true,"textposition":"auto","x":["Europe & Central Asia"],"xaxis":"x","y":[29378.21105336414],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Latin America & Caribbean ","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Latin America & Caribbean ","offsetgroup":"Latin America & Caribbean ","orientation":"v","showlegend":true,"textposition":"auto","x":["Latin America & Caribbean "],"xaxis":"x","y":[11454.913042455386],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Middle East & North Africa","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Middle East & North Africa","offsetgroup":"Middle East & North Africa","orientation":"v","showlegend":true,"textposition":"auto","x":["Middle East & North Africa"],"xaxis":"x","y":[15376.014997821934],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"North America","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"North America","offsetgroup":"North America","orientation":"v","showlegend":true,"textposition":"auto","x":["North America"],"xaxis":"x","y":[66809.3072006122],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"South Asia","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"South Asia","offsetgroup":"South Asia","orientation":"v","showlegend":true,"textposition":"auto","x":["South Asia"],"xaxis":"x","y":[2294.5549548055624],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sub-Saharan Africa ","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Sub-Saharan Africa ","offsetgroup":"Sub-Saharan Africa ","orientation":"v","showlegend":true,"textposition":"auto","x":["Sub-Saharan Africa "],"xaxis":"x","y":[2260.8872490888266],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6 ...

# %% [markdown]
# ## Home work question 4
#
# 1. remove the color legend.
# 2. Order the above bar chart based on the values of the average GDP per capita.

# %%
df_group = df_group.sort_values(by="GDP per capita (current US$)", ascending=False)
fig = px.bar(df_group,
             x="Region",
             y="GDP per capita (current US$)",
             title="Average GDP per Capita by Region (2020)")

fig.update_traces(showlegend=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="303af562-e273-4262-9c28-65edc4b33e3f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("303af562-e273-4262-9c28-65edc4b33e3f")) {                    Plotly.newPlot(                        "303af562-e273-4262-9c28-65edc4b33e3f",                        [{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["North America","Europe & Central Asia","Middle East & North Africa","East Asia & Pacific","Latin America & Caribbean ","South Asia","Sub-Saharan Africa "],"xaxis":"x","y":[66809.3072006122,29378.21105336414,15376.014997821934,15147.706591885904,11454.913042455386,2294.5549548055624,2260.8872490888266],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_ ...

# %% [markdown]
# # Homework-5

# %% [markdown]
# ###### **`Pick a few countries of your interest (for example, G7, BRICS, Nordic countries).`**

# %% [markdown]
# #### 1. Create a line chart showing the trend of Life Expectancy over time for comparing those countries.

# %%
import pandas as pd
import plotly.express as px

# Load the dataset
df = pd.read_csv("https://raw.githubusercontent.com/wcj365/python-stats-dataviz/refs/heads/master/fall2024/data/World_Development_Indicators_(WDI).csv")

# Define G7 countries
g7_countries = ['Canada', 'France', 'Germany', 'Italy', 'Japan', 'United Kingdom', 'United States']

# Filter the dataframe
df_filtered = df[df['Country'].isin(g7_countries)][['Country', 'Year', 'Life expectancy at birth, total (years)']].dropna()

# Create a line chart with Plotly Express
fig = px.line(df_filtered,
              x='Year',
              y='Life expectancy at birth, total (years)',
              color='Country',
              title='Trend of Life Expectancy Over Time for G7 Countries',
              labels={'Life expectancy at birth, total (years)': 'Life Expectancy (Years)', 'Year': 'Year'},
              line_dash='Country',  # Add line dash for better distinction
              markers=True)  # Add markers to the lines

fig.update_layout(legend_title_text='Country')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="208a4f8a-d5ce-4b69-b85d-e2ff2c8662c5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("208a4f8a-d5ce-4b69-b85d-e2ff2c8662c5")) {                    Plotly.newPlot(                        "208a4f8a-d5ce-4b69-b85d-e2ff2c8662c5",                        [{"hovertemplate":"Country=Canada\u003cbr\u003eYear=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Canada","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Canada","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[79.9921951219512,80.1126829268293,80.5436585365854,80.5436585365854,80.7246341463415,81.0660975609756,81.3221951219512,81.4826829268293,81.6636585365854,81.7448780487805,81.7843902439025,81.8156097560976,81.9248780487805,81.8329268292683,81.8439024390244,82.2287804878049,81.6704878048781,82.5966097560976],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=France\u003cbr\u003eYear=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"France","line":{"color":"#EF553B","dash":"dot"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"France","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[80.1634146341463,80.1634146341463,80.8121951219512,81.1121951219512,81.2146341463415,81.4146341463415,81.6634146341463,82.1146341463415,81.9682926829268,82.219512195122,82.719512195122,82.3219512195122,82.5731707317073,82.5756097560976,82.6756097560976,82.8268292682927,82.1756097560976,82.3243902439024],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Germany\u003cbr\u003eYear=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Germany","line":{"color":"#00cc96","dash":"dash"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Germany","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[78.6804878048781,78.9317073170732,79.1317073170732,79.5341463414634,79.7365853658537,79.8365853658537,79.9878048780488,80.4365853658537,80.5390243902439,80.490243902439,81.090243902439,80.6414634146341,80.990243902439,80.9926829268293,80.8926829268293,81.2926829268293,81.0414634146342,80.9009756097561],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Italy\u003cbr\u003eYear=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Italy","line":{"color":"#ab63fa","dash":"longdash"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Italy","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[80.7804878048781,80.7829268292683,81.2829268292683,81.4341463414634,81.4853658536585,81.6365853658537,82.0365853658537,82.1878048780488,82.2390243902439,82.690243902439,83.090243902439,82.5439024390244,83.2439024390244,82.9463414634147,83.3463414634146,83.4975609756098,82.1951219512195,82.7951219512195],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Japan\u003cbr\u003eYear=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Japan","line":{"color":"#FFA15A","dash":"dashdot"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Japan","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis": ...

# %% [markdown]
# #### 2. Pick a year from the data of the above few countries and create a scatter plot to compare their GDP per capita and life expectancy. The size of the dots represent the population. This type of scatter plot is called bubble chart.

# %%
import pandas as pd
import plotly.express as px

# Load the dataset
df = pd.read_csv("https://raw.githubusercontent.com/wcj365/python-stats-dataviz/refs/heads/master/fall2024/data/World_Development_Indicators_(WDI).csv")

# Define ASEAN countries
asean_countries = ['Brunei', 'Cambodia', 'Indonesia', 'Laos', 'Malaysia', 'Myanmar', 'Philippines', 'Singapore', 'Thailand', 'Vietnam']

# Choose a different year
year = 2018

# Filter the dataframe
df_filtered = df[(df['Country'].isin(asean_countries)) & (df['Year'] == year)][
    ['Country', 'GDP per capita (current US$)', 'Life expectancy at birth, total (years)', 'Population, total']
].dropna()

# Create a bubble chart with Plotly Express
fig = px.scatter(df_filtered,
                 x='GDP per capita (current US$)',
                 y='Life expectancy at birth, total (years)',
                 size='Population, total',
                 color='Country',
                 title=f'GDP per capita vs Life expectancy ({year}) for ASEAN Countries',
                 labels={'GDP per capita (current US$)': 'GDP per Capita (US$)',
                         'Life expectancy at birth, total (years)': 'Life Expectancy (Years)'},
                 hover_name='Country',
                 size_max=50,
                 log_x=True)  # Use log scale for GDP per capita

fig.update_layout(legend_title_text='Country')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="fff7e50f-9040-4fa2-b8af-a2ee7d7280c4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fff7e50f-9040-4fa2-b8af-a2ee7d7280c4")) {                    Plotly.newPlot(                        "fff7e50f-9040-4fa2-b8af-a2ee7d7280c4",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry=Cambodia\u003cbr\u003eGDP per Capita (US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Cambodia"],"legendgroup":"Cambodia","marker":{"color":"#636efa","size":[16025238.0],"sizemode":"area","sizeref":106826.7372,"symbol":"circle"},"mode":"markers","name":"Cambodia","orientation":"v","showlegend":true,"x":[1533.31598466079],"xaxis":"x","y":[70.561],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry=Indonesia\u003cbr\u003eGDP per Capita (US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Indonesia"],"legendgroup":"Indonesia","marker":{"color":"#EF553B","size":[267066843.0],"sizemode":"area","sizeref":106826.7372,"symbol":"circle"},"mode":"markers","name":"Indonesia","orientation":"v","showlegend":true,"x":[3902.661675559],"xaxis":"x","y":[70.338],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry=Malaysia\u003cbr\u003eGDP per Capita (US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Malaysia"],"legendgroup":"Malaysia","marker":{"color":"#00cc96","size":[32399271.0],"sizemode":"area","sizeref":106826.7372,"symbol":"circle"},"mode":"markers","name":"Malaysia","orientation":"v","showlegend":true,"x":[11073.9789704691],"xaxis":"x","y":[75.644],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry=Myanmar\u003cbr\u003eGDP per Capita (US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Myanmar"],"legendgroup":"Myanmar","marker":{"color":"#ab63fa","size":[52666014.0],"sizemode":"area","sizeref":106826.7372,"symbol":"circle"},"mode":"markers","name":"Myanmar","orientation":"v","showlegend":true,"x":[1288.41808699092],"xaxis":"x","y":[66.465],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry=Philippines\u003cbr\u003eGDP per Capita (US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Philippines"],"legendgroup":"Philippines","marker":{"color":"#FFA15A","size":[108568836.0],"sizemode":"area","sizeref":106826.7372,"symbol":"circle"},"mode":"markers","name":"Philippines","orientation":"v","showlegend":true,"x":[3194.67270132209],"xaxis":"x","y":[71.689],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry=Singapore\u003cbr\u003eGDP per Capita (US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Singapore"],"legendgroup":"Singapore","marker":{"color":"#19d3f3","size":[5638676.0],"sizemode":"area","sizeref":106826.7372,"symbol":"circle"},"mode":"markers","name":"Singapore","orientation":"v","showlegend":true,"x":[66836.52 ...

# %% [markdown]
# #### 3. Bonus - compute the average GDP per capita, the average life expectancy, and the total population for each year of all the seven regions (aggregation) and repeat 1 and 2 using the aggregated data for all regions

# %%
import pandas as pd
import plotly.express as px

# Load the dataset
df = pd.read_csv("https://raw.githubusercontent.com/wcj365/python-stats-dataviz/refs/heads/master/fall2024/data/World_Development_Indicators_(WDI).csv")

# List of the seven regions
regions = ['East Asia & Pacific', 'Europe & Central Asia', 'Latin America & Caribbean',
           'Middle East & North Africa', 'North America', 'South Asia', 'Sub-Saharan Africa']

# Aggregate data
df_aggregated = df[df['Region'].isin(regions)].groupby(['Year', 'Region']).agg(
    avg_gdp_per_capita=('GDP per capita (current US$)', 'mean'),
    avg_life_expectancy=('Life expectancy at birth, total (years)', 'mean'),
    total_population=('Population, total', 'sum')
).reset_index()

# 1. Line chart showing the trend of Life Expectancy over time for all regions
fig1 = px.line(df_aggregated,
               x='Year',
               y='avg_life_expectancy',
               color='Region',
               title='Trend of Average Life Expectancy Over Time for Seven World Regions',
               labels={'avg_life_expectancy': 'Average Life Expectancy (Years)', 'Year': 'Year'},
               line_dash='Region',
               markers=True)

fig1.update_layout(legend_title_text='Region')
fig1.show()

# 2. Bubble chart comparing GDP per capita and life expectancy for a specific year
year = 2020  # You can change this to any year in the dataset

# Filter data for the selected year
df_year = df_aggregated[df_aggregated['Year'] == year]

fig2 = px.scatter(df_year,
                  x='avg_gdp_per_capita',
                  y='avg_life_expectancy',
                  size='total_population',
                  color='Region',
                  hover_name='Region',
                  title=f'Average GDP per Capita vs Average Life Expectancy ({year}) for Seven World Regions',
                  labels={'avg_gdp_per_capita': 'Average GDP per Capita (current US$)',
                          'avg_life_expectancy': 'Average Life Expectancy (Years)',
                          'total_population': 'Total Population'},
                  size_max=60,
                  log_x=True)

fig2.update_layout(legend_title_text='Region')
fig2.show()

# Print the aggregated data for verification
print(df_year)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5c73057d-5b05-410e-9bab-6c0e64e20772" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5c73057d-5b05-410e-9bab-6c0e64e20772")) {                    Plotly.newPlot(                        "5c73057d-5b05-410e-9bab-6c0e64e20772",                        [{"hovertemplate":"Region=East Asia & Pacific\u003cbr\u003eYear=%{x}\u003cbr\u003eAverage Life Expectancy (Years)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"East Asia & Pacific","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"East Asia & Pacific","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[70.82474605451937,71.03525226480836,71.35182855093257,71.53284791965567,71.55289167862267,71.93134289813486,72.1956987087518,72.4136262553802,72.63352725968436,72.85580703012913,73.06722883787661,73.2169756097561,73.38525538020087,73.59137517934003,73.8483737446198,74.0432230989957,74.14365566714491,73.64341893830704,null],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Europe & Central Asia\u003cbr\u003eYear=%{x}\u003cbr\u003eAverage Life Expectancy (Years)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Europe & Central Asia","line":{"color":"#EF553B","dash":"dot"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Europe & Central Asia","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[74.8951915742794,74.99792727272728,75.27233303769401,75.49948070953438,75.9008713968958,76.20778137472284,76.45108115299335,76.83067450110866,77.04216097560976,77.25882793791575,77.56068115299334,77.53420044345899,77.83207627494457,77.99858669623062,78.13177738359202,78.39830288248336,77.36474589800444,77.08593215077606,null],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Middle East & North Africa\u003cbr\u003eYear=%{x}\u003cbr\u003eAverage Life Expectancy (Years)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Middle East & North Africa","line":{"color":"#00cc96","dash":"dash"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Middle East & North Africa","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[72.37166666666667,72.64277235772359,72.80688966318235,73.09993147502904,73.40060975609757,73.75654006968641,74.1584761904762,74.24478281068525,74.24767711962834,74.37635423925667,74.45095238095239,74.7327038327526,74.97042740998839,75.34821718931474,75.54567711962834,75.72125783972126,74.67093147502904,74.36790360046457,null],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=North America\u003cbr\u003eYear=%{x}\u003cbr\u003eAverage Life Expectancy (Years)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"North America","line":{"color":"#ab63fa","dash":"longdash"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"North America","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[79.53333333333335,78.50916260162603,78.60548780487807,79.29748780487807,79.1288861788618,79.81744715447154,80.1208861788618,80.5090487804878,80.55904065040653,80.15944715447158,80.0479512195122,80.47461788617886,80.35730081300814,80.90765040650406,80.4359756097561,80.68319512195124,79.92899186991873,79.4019593495935,null],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=South Asia\u003cbr\u003eYear=%{x}\u003cbr\u003eAverage Life Expectancy (Years)=%{y}\u003c ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="da17355f-cc06-499f-b717-b5a28bd2c1e7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("da17355f-cc06-499f-b717-b5a28bd2c1e7")) {                    Plotly.newPlot(                        "da17355f-cc06-499f-b717-b5a28bd2c1e7",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eRegion=East Asia & Pacific\u003cbr\u003eAverage GDP per Capita (current US$)=%{x}\u003cbr\u003eAverage Life Expectancy (Years)=%{y}\u003cbr\u003eTotal Population=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["East Asia & Pacific"],"legendgroup":"East Asia & Pacific","marker":{"color":"#636efa","size":[2340350511.0],"sizemode":"area","sizeref":650097.3641666666,"symbol":"circle"},"mode":"markers","name":"East Asia & Pacific","orientation":"v","showlegend":true,"x":[15821.020760755067],"xaxis":"x","y":[74.14365566714491],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eRegion=Europe & Central Asia\u003cbr\u003eAverage GDP per Capita (current US$)=%{x}\u003cbr\u003eAverage Life Expectancy (Years)=%{y}\u003cbr\u003eTotal Population=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Europe & Central Asia"],"legendgroup":"Europe & Central Asia","marker":{"color":"#EF553B","size":[922353365.0],"sizemode":"area","sizeref":650097.3641666666,"symbol":"circle"},"mode":"markers","name":"Europe & Central Asia","orientation":"v","showlegend":true,"x":[34495.485465095706],"xaxis":"x","y":[77.36474589800444],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eRegion=Middle East & North Africa\u003cbr\u003eAverage GDP per Capita (current US$)=%{x}\u003cbr\u003eAverage Life Expectancy (Years)=%{y}\u003cbr\u003eTotal Population=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Middle East & North Africa"],"legendgroup":"Middle East & North Africa","marker":{"color":"#00cc96","size":[479966649.0],"sizemode":"area","sizeref":650097.3641666666,"symbol":"circle"},"mode":"markers","name":"Middle East & North Africa","orientation":"v","showlegend":true,"x":[13990.928453691733],"xaxis":"x","y":[74.67093147502904],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eRegion=North America\u003cbr\u003eAverage GDP per Capita (current US$)=%{x}\u003cbr\u003eAverage Life Expectancy (Years)=%{y}\u003cbr\u003eTotal Population=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["North America"],"legendgroup":"North America","marker":{"color":"#ab63fa","size":[369582571.0],"sizemode":"area","sizeref":650097.3641666666,"symbol":"circle"},"mode":"markers","name":"North America","orientation":"v","showlegend":true,"x":[71556.7328644806],"xaxis":"x","y":[79.92899186991873],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eRegion=South Asia\u003cbr\u003eAverage GDP per Capita (current US$)=%{x}\u003cbr\u003eAverage Life Expectancy (Years)=%{y}\u003cbr\u003eTotal Population=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["South Asia"],"legendgroup":"South Asia","marker":{"color":"#FFA15A","size":[1882531620.0],"sizemode":"area","sizeref":650097.3641666666,"symbol":"circle"},"mode":"markers","name":"South Asia","orientation":"v","showlegend":true,"x":[2671.328827387151],"xaxis":"x","y":[71.010625],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks": ...
#     Year                      Region  avg_gdp_per_capita  avg_life_expectancy  \
# 80  2020         East Asia & Pacific        15821.020761            74.143656
# 81  2020       Europe & Central Asia        34495.485465            77.364746
# 82  2020  Middle East & North Africa        13990.928454            74.670931
# 83  2020               North America        71556.732864            79.928992
# 84  2020                  South Asia         2671.328827            71.010625
#
#     total_population
# 80      2.340351e+09
# 81      9.223534e+08
# 82      4.799666e+08
# 83      3.695826e+08
# 84      1.882532e+09

# %% [markdown]
# ## HOMEWORK - 6

# %% [markdown]
# #### Question 1

# %% [markdown]
# for the Quad time series comparison chart above, try to add country name to the end of the line and then remove the color legend.

# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

df = pd.read_csv("https://raw.githubusercontent.com/wcj365/python-stats-dataviz/refs/heads/master/fall2024/data/World_Development_Indicators_(WDI).csv")

# Filter data for the four Quad countries (USA, CHN, IND, RUS)
df_quadcountries = df[df["Country Code"].isin(["USA", "CHN", "IND", "RUS"])]

# Create a line chart for GDP per Capita over time for Quad countries
fig = px.line(df_quadcountries,
              x='Year',
              y='GDP per capita (current US$)',
              color='Country',
              labels={
                  'GDP per capita (current US$)': 'GDP per Capita (Current US$)',
                  'Year': 'Year'
              },
              title='GDP per Capita Over Time for Quad Countries')

# Remove the color legend
fig.update_layout(showlegend=False)

# Add country labels to the end of each line
quad_countries = ["USA", "CHN", "IND", "RUS"]
for country in quad_countries:
    # Get the last data point for each country (most recent year)
    country_data = df_quadcountries[df_quadcountries["Country Code"] == country]
    last_year = country_data["Year"].max()
    last_value = country_data[country_data["Year"] == last_year]["GDP per capita (current US$)"].values[0]

    # Add annotation (text label) at the end of each line
    fig.add_annotation(
        x=last_year,
        y=last_value,
        text=country,
        showarrow=False,
        xanchor='left',
        yanchor='middle',
        font=dict(size=12, color='black')
    )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="afdba6eb-ab14-468d-a16d-22b5fa189a7f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("afdba6eb-ab14-468d-a16d-22b5fa189a7f")) {                    Plotly.newPlot(                        "afdba6eb-ab14-468d-a16d-22b5fa189a7f",                        [{"hovertemplate":"Country=China\u003cbr\u003eYear=%{x}\u003cbr\u003eGDP per Capita (Current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"China","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"China","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[1508.66791563578,1753.41419162417,2099.2194300786,2693.95873162278,3468.32706308591,3832.22745696438,4550.47394361131,5614.3860223103,6300.58217952904,7020.38607424065,7636.0743401587,8016.44559491162,8094.39016730811,8817.04560829162,9905.40638307759,10143.8602205959,10408.7195541075,12617.5051041181,12720.2163182363],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=India\u003cbr\u003eYear=%{x}\u003cbr\u003eGDP per Capita (Current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"India","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"India","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[624.105094381691,710.509344848758,802.013742049265,1022.73246704551,993.503405266506,1096.63613605519,1350.63447029491,1449.60330101563,1434.01798721629,1438.05700508042,1559.86377870535,1590.17433135955,1714.27953740039,1957.96981329558,1974.3777314935,2050.1638002619,1913.21973278751,2238.12714218765,2410.88802070689],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Russian Federation\u003cbr\u003eYear=%{x}\u003cbr\u003eGDP per Capita (Current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Russian Federation","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Russian Federation","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[4102.36474609375,5323.455078125,6920.19970703125,9101.2392578125,11635.2841796875,8562.82421875,10674.990234375,14311.064453125,15420.859375,15974.6220703125,14095.646484375,9313.021484375,8704.89453125,10720.33203125,11287.3544921875,11536.2587890625,10194.44140625,12532.05078125,15270.7060546875],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=United States\u003cbr\u003eYear=%{x}\u003cbr\u003eGDP per Capita (Current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"United States","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"United States","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[41724.6316287624,44123.4070679055,46302.0008800056,48050.2237771135,48570.0459804586,47194.9433547336,48650.6431283336,50065.9665041742,51784.4185738837,53291.1276891406,55123.8497869046,56762.7294515989,57866.7449341091,59907.754260885,62823.309438197,65120.3946628653,63528.6343027508,70219.472454115,76329.5822652029],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.55555555555555 ...

# %% [markdown]
# ### Question 2

# %% [markdown]
# Round the Average GDP for each region to 2 decimal points. Sort the bar according to GDP either in ascending order. Currently, it is ordered alphabetically.

# %%
# Display the shape of the dataframe
print(df.shape)
# Out:
# (4123, 9)

# %%
df_filtered = df[['Country Code', 'Country', 'Region', 'Year', 'GDP per capita (current US$)']]

# Group by Region and Year, calculating the average GDP per capita
aggregated_df = df_filtered.groupby(['Region', 'Year']).agg(
    Average_GDP=('GDP per capita (current US$)', 'mean')
).reset_index()

# Round the Average GDP per capita to 2 decimal points
aggregated_df['Average_GDP'] = aggregated_df['Average_GDP'].round(2)
print(aggregated_df['Average_GDP'])

# Get the latest year data for each region
latest_year = aggregated_df['Year'].max()
latest_df = aggregated_df[aggregated_df['Year'] == latest_year]

# Sort the DataFrame by Average GDP in ascending order
latest_df = latest_df.sort_values(by='Average_GDP', ascending=True)
print(latest_df)
# Out:
# 0       9855.98
# 1      10587.14
# 2      11255.63
# 3      12550.95
# 4      13434.66
# 5      12631.91
# 6      14068.85
# 7      16014.21
# 8      16798.99
# 9      17213.33
# 10     17395.25
# 11     15955.33
# 12     16183.49
# 13     17238.07
# 14     18083.53
# 15     17906.00
# 16     15821.02
# 17     17629.91
# 18     17520.50
# 19     24463.16
# 20     25938.84
# 21     28166.11
# 22     33274.07
# 23     35251.70
# 24     30980.82
# 25     31303.47
# 26     34304.75
# 27     32496.99
# 28     34480.98
# 29     35462.90
# 30     31197.16
# 31     32062.36
# 32     33617.24
# 33     36165.93
# 34     35566.32
# 35     34495.49
# 36     39320.61
# 37     35338.53
# 38      7321.82
# 39      8166.28
# 40     11052.58
# 41     11924.33
# 42     12585.77
# 43     11703.17
# 44     12172.21
# 45     13495.64
# 46     13594.60
# 47     13765.82
# 48     14443.05
# 49     14248.32
# 50     14286.02
# 51     14697.23
# 52     15005.52
# 53     15465.70
# 54     13405.54
# 55     15923.32
# 56     17192.26
# 57     10118.18
# 58     11970.27
# 59     13378.45
# 60     14450.03
# 61     17150.99
# 62     13799.08
# 63     15578.72
# 64     17617.76
# 65     18595.69
# 66     18502.59
# 67     18036.17
# 68     14895.55
# 69     14366.72
# 70     15235.81
# 71     16439.89
# 72     16111.83
# 73     13990.93
# 74     16529.61
# 75     21168.21
# 76     48075.88
# 77     52129.32
# 78     60675.97
# 79     65665.84
# 80     67405.35
# 81     63159.67
# 82     66029.34
# 83     66687.94
# 84     67628.46
# 85     68465.98
# 86     68182.51
# 87     67454.83
# 88     69022.74
# 89     72285.92
# 90     74140.89
# 91     75882.57
# 92     71556.73
# 93     78117.59
# 94     83340.68
# 95      1067.55
# 96      1103.83
# 97      1320.33
# 98      1552.74
# 99      1761.33
# 100     1781.42
# 101     2059.99
# 102     2251.95
# 103     2283.08
# 104     2424.43
# 105     2596.68
# 106     2732.95
# 107     2867.73
# 108     3113.18
# 109     3249.66
# 110     3286.25
# 111     2671.33
# 112     3177.55
# 113     3859.97
# 114     1432.80
# 115     1668.96
# 116     1839.39
# 117     2070.65
# 118     2341.38
# 119     2071.92
# 120     2310.38
# 121     2643.56
# 122     2665.35
# 123     2689.46
# 124     2695.87
# 125     2267.52
# 126     2221.63
# 127     2382.71
# 128     2497.29
# 129     2413.50
# 130     2090.56
# 131     2367.10
# 132     2457.32
# Name: Average_GDP, dtype: float64
#                          Region  Year  Average_GDP
# 132         Sub-Saharan Africa   2022      2457.32
# 113                  South Asia  2022      3859.97
# 56   Latin America & Caribbean   2022     17192.26
# 18          East Asia & Pacific  2022     17520.50
# 75   Middle East & North Africa  2022     21168.21
# 37        Europe & Central Asia  2022     35338.53
# 94                North America  2022     83340.68

# %%
fig = px.bar(
    latest_df,
    x='Region',
    y='Average_GDP',
    color = 'Region',
    title=f'Average GDP per Capita by Region in {latest_year} (Sorted by GDP)',
    labels={'Average_GDP': 'Average GDP per Capita (Current US$)', 'Region': 'Region'},
    text='Average_GDP',
    height=600,
    width=1200
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ee194647-55c4-46ea-b3b8-800c2c5d9502" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ee194647-55c4-46ea-b3b8-800c2c5d9502")) {                    Plotly.newPlot(                        "ee194647-55c4-46ea-b3b8-800c2c5d9502",                        [{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eAverage GDP per Capita (Current US$)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sub-Saharan Africa ","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Sub-Saharan Africa ","offsetgroup":"Sub-Saharan Africa ","orientation":"v","showlegend":true,"text":[2457.32],"textposition":"auto","x":["Sub-Saharan Africa "],"xaxis":"x","y":[2457.32],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eAverage GDP per Capita (Current US$)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"South Asia","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"South Asia","offsetgroup":"South Asia","orientation":"v","showlegend":true,"text":[3859.97],"textposition":"auto","x":["South Asia"],"xaxis":"x","y":[3859.97],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eAverage GDP per Capita (Current US$)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Latin America & Caribbean ","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Latin America & Caribbean ","offsetgroup":"Latin America & Caribbean ","orientation":"v","showlegend":true,"text":[17192.26],"textposition":"auto","x":["Latin America & Caribbean "],"xaxis":"x","y":[17192.26],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eAverage GDP per Capita (Current US$)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"East Asia & Pacific","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"East Asia & Pacific","offsetgroup":"East Asia & Pacific","orientation":"v","showlegend":true,"text":[17520.5],"textposition":"auto","x":["East Asia & Pacific"],"xaxis":"x","y":[17520.5],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eAverage GDP per Capita (Current US$)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Middle East & North Africa","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Middle East & North Africa","offsetgroup":"Middle East & North Africa","orientation":"v","showlegend":true,"text":[21168.21],"textposition":"auto","x":["Middle East & North Africa"],"xaxis":"x","y":[21168.21],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eAverage GDP per Capita (Current US$)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Europe & Central Asia","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Europe & Central Asia","offsetgroup":"Europe & Central Asia","orientation":"v","showlegend":true,"text":[35338.53],"textposition":"auto","x":["Europe & Central Asia"],"xaxis":"x","y":[35338.53],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eAverage GDP per Capita (Current US$)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"North America","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"North America","offsetgroup":"North America","orientation":"v","showlegend":true,"text":[83340.68],"textposition":"auto","x":["North America"],"xaxis":"x","y":[83340.68],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039 ...

# %% [markdown]
# ### QUESTION 3

# %% [markdown]
# Group the dataset by Region and Income Group, calculate the average, min, and max of GDP per Capita & life Expentancy, total, average, min, and max of population, then save the result to Excel.

# %%
# Display the shape of the dataframe
print(df.shape)
# Out:
# (4123, 9)

# %%
df_filtered = df[['Country Code', 'Country', 'Region', 'Income Group',
                   'Year', 'GDP per capita (current US$)',
                   'Life expectancy at birth, total (years)',
                   'Population, total']]

# Group by Region and Income Group and calculate the required statistics
stats_grouped = df_filtered.groupby(['Region', 'Income Group']).agg(
    Average_GDP=('GDP per capita (current US$)', 'mean'),
    Min_GDP=('GDP per capita (current US$)', 'min'),
    Max_GDP=('GDP per capita (current US$)', 'max'),
    Average_Life_Expectancy=('Life expectancy at birth, total (years)', 'mean'),
    Min_Life_Expectancy=('Life expectancy at birth, total (years)', 'min'),
    Max_Life_Expectancy=('Life expectancy at birth, total (years)', 'max'),
    Total_Population=('Population, total', 'sum'),
    Average_Population=('Population, total', 'mean'),
    Min_Population=('Population, total', 'min'),
    Max_Population=('Population, total', 'max')
).reset_index()

# Display the grouped statistics
print(stats_grouped)


# Save the result to an Excel file
stats_grouped.to_excel("region_income_group_stats.xlsx", index=False)
# Out:
#                         Region         Income Group   Average_GDP  \
# 0          East Asia & Pacific          High income  33874.637356
# 1          East Asia & Pacific           Low income           NaN
# 2          East Asia & Pacific  Lower middle income   2122.056616
# 3          East Asia & Pacific  Upper middle income   5829.903445
# 4        Europe & Central Asia          High income  47933.522488
# 5        Europe & Central Asia  Lower middle income   1687.491133
# 6        Europe & Central Asia  Upper middle income   6046.010575
# 7   Latin America & Caribbean           High income  23970.748125
# 8   Latin America & Caribbean   Lower middle income   1879.755160
# 9   Latin America & Caribbean        Not classified  10341.209099
# 10  Latin America & Caribbean   Upper middle income   7042.758897
# 11  Middle East & North Africa          High income  34258.951233
# 12  Middle East & North Africa           Low income   2523.869070
# 13  Middle East & North Africa  Lower middle income   3906.016421
# 14  Middle East & North Africa  Upper middle income   5680.306747
# 15               North America          High income  67679.379373
# 16                  South Asia           Low income    473.657905
# 17                  South Asia  Lower middle income   1708.225731
# 18                  South Asia  Upper middle income   8001.072809
# 19         Sub-Saharan Africa           High income  13272.154230
# 20         Sub-Saharan Africa            Low income    629.082869
# 21         Sub-Saharan Africa   Lower middle income   1735.313146
# 22         Sub-Saharan Africa   Upper middle income   7708.803806
#
#          Min_GDP        Max_GDP  Average_Life_Expectancy  Min_Life_Expectancy  \
# 0    4644.355494   90873.602487                79.008345            58.072000
# 1            NaN            NaN                71.391444            68.911000
# 2     223.229847    5045.504700                68.286722            56.506000
# 3    1136.755211   16743.376740                70.263271            63.226000
# 4    3494.990564  240862.182448                79.282116            68.422439
